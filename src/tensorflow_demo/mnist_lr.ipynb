# %%
from tensorflow.keras import layers
from tensorflow.keras import datasets
from tensorflow import keras

# %%
# network and training
EPOCHS = 20
BATCH_SIZE = 256
VERBOSE = 1
NB_CLASSES = 10  # number of outputs = number of digits
N_HIDDEN = 128
VALIDATION_SPLIT = 0.2  # how much TRAIN is reserved for VALIDATION
DROPOUT = 0.3
OPTMIZER = keras.optimizers.SGD(learning_rate=0.001)

# %%
(X_train, Y_train), (X_test, Y_test) = datasets.mnist.load_data()

# %%
#X_train is 60000 rows of 28x28 values --> reshaped in 60000 x 784
RESHAPED = 784
#
X_train = X_train.reshape(60000, RESHAPED)
X_test = X_test.reshape(10000, RESHAPED)
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')

#normalize in [0,1]
X_train, X_test = X_train / 255.0, X_test / 255.0
Y_train = keras.utils.to_categorical(Y_train, NB_CLASSES)
Y_test = keras.utils.to_categorical(Y_test, NB_CLASSES)

X_train.shape, Y_train.shape, X_test.shape, Y_test.shape
# Out:
# ((60000, 784), (60000, 10), (10000, 784), (10000, 10))

# %%
model = keras.models.Sequential()
model.add(layers.Dense(N_HIDDEN,
                       input_shape=(RESHAPED,),
                       name='dense_layer',
                       activation='relu'))
model.add(layers.Dropout(DROPOUT))
model.add(layers.Dense(N_HIDDEN,
                       name='dense_layer_2',
                       activation='relu'))
model.add(layers.Dropout(DROPOUT))
model.add(layers.Dense(NB_CLASSES,
                       name='dense_layer_3',
                       activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_layer (Dense)          (None, 128)               100480
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_layer_2 (Dense)        (None, 128)               16512
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_layer_3 (Dense)        (None, 10)                1290
# =================================================================
# Total params: 118,282
# Trainable params: 118,282
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer=OPTMIZER,
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.fit(X_train, Y_train, batch_size=BATCH_SIZE,
          epochs=EPOCHS, verbose=VERBOSE, validation_split=VALIDATION_SPLIT)
# Out:
# Epoch 1/20
# 188/188 [==============================] - 2s 6ms/step - loss: 2.3290 - accuracy: 0.1254 - val_loss: 2.2436 - val_accuracy: 0.1846
# Epoch 2/20
# 188/188 [==============================] - 1s 5ms/step - loss: 2.2477 - accuracy: 0.1768 - val_loss: 2.1706 - val_accuracy: 0.3290
# Epoch 3/20
# 188/188 [==============================] - 1s 5ms/step - loss: 2.1813 - accuracy: 0.2368 - val_loss: 2.1030 - val_accuracy: 0.4366
# Epoch 4/20
# 188/188 [==============================] - 1s 5ms/step - loss: 2.1195 - accuracy: 0.2948 - val_loss: 2.0343 - val_accuracy: 0.5047
# Epoch 5/20
# 188/188 [==============================] - 1s 5ms/step - loss: 2.0584 - accuracy: 0.3425 - val_loss: 1.9615 - val_accuracy: 0.5506
# Epoch 6/20
# 188/188 [==============================] - 1s 5ms/step - loss: 1.9934 - accuracy: 0.3865 - val_loss: 1.8834 - val_accuracy: 0.5872
# Epoch 7/20
# 188/188 [==============================] - 1s 5ms/step - loss: 1.9253 - accuracy: 0.4246 - val_loss: 1.8007 - val_accuracy: 0.6122
# Epoch 8/20
# 188/188 [==============================] - 1s 5ms/step - loss: 1.8564 - accuracy: 0.4525 - val_loss: 1.7153 - val_accuracy: 0.6318
# Epoch 9/20
# 188/188 [==============================] - 1s 6ms/step - loss: 1.7834 - accuracy: 0.4785 - val_loss: 1.6289 - val_accuracy: 0.6497
# Epoch 10/20
# 188/188 [==============================] - 1s 5ms/step - loss: 1.7113 - accuracy: 0.5035 - val_loss: 1.5430 - val_accuracy: 0.6658
# Epoch 11/20
# 188/188 [==============================] - 1s 5ms/step - loss: 1.6420 - accuracy: 0.5229 - val_loss: 1.4592 - val_accuracy: 0.6842
# Epoch 12/20
# 188/188 [==============================] - 1s 5ms/step - loss: 1.5762 - accuracy: 0.5400 - val_loss: 1.3789 - val_accuracy: 0.7013
# Epoch 13/20
# 188/188 [==============================] - 1s 6ms/step - loss: 1.5091 - accuracy: 0.5559 - val_loss: 1.3030 - val_accuracy: 0.7203
# Epoch 14/20
# 188/188 [==============================] - 1s 5ms/step - loss: 1.4457 - accuracy: 0.5758 - val_loss: 1.2323 - val_accuracy: 0.7362
# Epoch 15/20
# 188/188 [==============================] - 1s 5ms/step - loss: 1.3956 - accuracy: 0.5869 - val_loss: 1.1678 - val_accuracy: 0.7532
# Epoch 16/20
# 188/188 [==============================] - 1s 5ms/step - loss: 1.3380 - accuracy: 0.6036 - val_loss: 1.1077 - val_accuracy: 0.7671
# Epoch 17/20
# 188/188 [==============================] - 1s 5ms/step - loss: 1.2933 - accuracy: 0.6153 - val_loss: 1.0538 - val_accuracy: 0.7803
# Epoch 18/20
# 188/188 [==============================] - 1s 5ms/step - loss: 1.2490 - accuracy: 0.6240 - val_loss: 1.0050 - val_accuracy: 0.7903
# Epoch 19/20
# 188/188 [==============================] - 1s 5ms/step - loss: 1.2132 - accuracy: 0.6344 - val_loss: 0.9609 - val_accuracy: 0.7988
# Epoch 20/20
# 188/188 [==============================] - 1s 6ms/step - loss: 1.1703 - accuracy: 0.6480 - val_loss: 0.9207 - val_accuracy: 0.8055
